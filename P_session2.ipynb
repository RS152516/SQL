# %% [raw]
# # loops
# Loops are used to execute a block of code repeatedly until a condition is met or all items in a sequence are processed. The main types are For loops (iterating over sequences) and While loops (executing code based on a condition).

# %%
#for loop 
#For loops is used to iterate over a sequence such as a list, tuple, string or range.
#It executes a block of code once for each item in the sequence.
# for loop example

# %%
# print all numbers in the range using fo
n = 4
for i in range(0, n):
    print(i)
# Out:
# 0
# 1
# 2
# 3

# %% [markdown]
# While loop
# repeatedly executes a block of code as long as the given condition remains true. When the condition becomes false, the line immediately after the loop in the program is executed.

# %%
#while loop example , print hello world untill the condition is met
cnt = 0
while (cnt < 3):
    cnt = cnt + 1
    print("Hello world")

# %% [markdown]
# # REAL time example for , while and for loop
#
# while loop : thermostat , entering password
# in thermostat for the required condition is met , the thermostat stops which means  breaks the condition and comes out of theloop  , in the same way for entering password .
#
# # for loop example
# in online shoping , Imagine you added multiple items to your cart, and Python needs to print each item one by one.

# %%
# for loop using indexing 
names = ["Rama", "Krishna", "Sita", "John"]

for i in range(len(names)):
    print( names[i])
# Out:
# Rama
# Krishna
# Sita
# John

# %% [markdown]
# # string
# Strings are sequence of characters written inside quotes. It can include letters, numbers, symbols and spaces. Python does not have a separate character type.
#
# A single character is treated as a string of length one.
# Strings are commonly used for text handling and manipulation.
# # Strings can be created using either single ('...') or double ("...") quotes. Both behave the same.

# %%
# creating a string 
a = 'MI'  
b = "MumbaiIndians"  
print(a)
print(b)
# Out:
# MI
# MumbaiIndians

# %% [markdown]
# # Accessing Characters in String
# Strings are indexed sequences. Positive indices start at 0 from the left, negative indices start at -1 from the right

# %%
s = "ABCDEF"
print(s[0])   
print(s[4])
print(s[-6])
print(s[-2])
# Out:
# A
# E
# A
# E

# %% [markdown]
# # STRING SLICING
# Slicing is a way to extract a portion of a string by specifying the start and end indexes. The syntax for slicing is string[start:end], where start starting index and end is stopping index (excluded).

# %%
s = "ABCDEF"
print(s[1:4])    
print(s[:3])     
print(s[3:])    
print(s[::3])
# Out:
# BCD
# ABC
# DEF
# AD

# %% [markdown]
# # STRING STEPSIZE
# Step size is used in string slicing.
# SYNTAX : string[start:end:step]
# start → where to start
# end   → where to stop
# step  → how many characters to jump

# %%
text = "python"

print(text[0:5:2])
# Out:
# pto

# %%
#REVERSE A STRING USING STEPSIZE
text = "python"

print(text[::-1])
# Out:
# nohtyp

# %%
# REVERSE A STRING USING FOR LOOP 
text = "python"
reverse_text = ""

for char in text:
    reverse_text = char + reverse_text
print(reverse_text)
# Out:
# nohtyp

# %% [markdown]
# Common String Methods
# Python provides various built-in methods to manipulate strings.
#     Below are some of the most useful methods:
#
# 1. len(): returns the total number of characters in a string (including spaces and punctuation).
# 2. upper() and lower(): upper() method converts all characters to uppercase whereas,
#    lower() method converts all characters to lowercase.

# %%
# LENGTH OF STRING 
A= 'PYTHON'
print(len(A))
# Out:
# 6

# %%
#converting upper and lower char in string 
A='Python'
print(A.upper())
print(A.lower())
# Out:
# PYTHON
# python

# %% [markdown]
# Concatenating and Repeating Strings
# 1. Concatenation: Strings can be combined by using + operator.
# 2. 2.Repetition: A string can be repeated multiple times using *.

# %%
s1 = "Hello"
s2 = "World"
print(s1  +" "+  s2)
print(s1 * 4)
# Out:
# Hello World
# HelloHelloHelloHello
